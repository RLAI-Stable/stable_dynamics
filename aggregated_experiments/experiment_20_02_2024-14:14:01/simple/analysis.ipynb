# %% [markdown]
# # Load files

# %%
import pandas as pd
pd.options.display.float_format = '{:.8}'.format


# Read CSV files into pandas DataFrames
model_eval_df = pd.read_csv('model_eval.csv')
model_epochs_df = pd.read_csv('model_epochs.csv')

# %% [markdown]
# # Filter epochs DF to get only the test loss

# %%
model_epochs_df = model_epochs_df[model_epochs_df['train_or_test'] == 'TEST']
display(model_epochs_df)
# Out:
#                         timestamp  learning_rate            model_type
# 10     2024-02-11 04:41:44.081544         0.0003  SIMPLE_300-SKIP_N_20  \
# 21     2024-02-11 04:49:48.870611         0.0003  SIMPLE_300-SKIP_N_20
# 32     2024-02-11 04:57:06.045085         0.0003  SIMPLE_300-SKIP_N_20
# 43     2024-02-11 05:03:33.480042         0.0003  SIMPLE_300-SKIP_N_20
# 54     2024-02-11 05:10:10.879695         0.0003  SIMPLE_300-SKIP_N_20
# ...                           ...            ...                   ...
# 26619  2024-02-11 05:43:58.831641         0.0003  SIMPLE_300-SKIP_N_20
# 26630  2024-02-11 05:52:00.537914         0.0003  SIMPLE_300-SKIP_N_20
# 26641  2024-02-11 05:59:52.058513         0.0003  SIMPLE_300-SKIP_N_20
# 26652  2024-02-11 06:08:01.628614         0.0003  SIMPLE_300-SKIP_N_20
# 26663  2024-02-11 06:16:11.029702         0.0003  SIMPLE_300-SKIP_N_20
#
#       train_or_test  epoch          loss                 model_parameters
# 10             TEST     10 2.2701059e-06  skip_20_LR_0.0003_LAYERSIZE_300  \
# 21             TEST     20 2.0554099e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 32             TEST     30 1.9151716e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 43             TEST     40 1.8329908e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 54             TEST     50 1.8466332e-06  skip_20_LR_0.0003_LAYERSIZE_300
# ...             ...    ...           ...                              ...
# 26619          TEST     20 1.9581675e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 26630          TEST     30 1.9299566e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 26641          TEST     40 1.8713605e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 26652          TEST     50 1.7574349e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 26663          TEST     60 1.7370831e-06  skip_20_LR_0.0003_LAYERSIZE_300
#
#                                        uuid
# 10     53231d1c-3b05-404d-910c-4a76401ae286
# 21     53231d1c-3b05-404d-910c-4a76401ae286
# 32     53231d1c-3b05-404d-910c-4a76401ae286
# 43     53231d1c-3b05-404d-910c-4a76401ae286
# 54     53231d1c-3b05-404d-910c-4a76401ae286
# ...                                     ...
# 26619  28c106a0-9987-4d49-8b3f-b782711cdbdf
# 26630  28c106a0-9987-4d49-8b3f-b782711cdbdf
# 26641  28c106a0-9987-4d49-8b3f-b782711cdbdf
# 26652  28c106a0-9987-4d49-8b3f-b782711cdbdf
# 26663  28c106a0-9987-4d49-8b3f-b782711cdbdf
#
# [2424 rows x 8 columns]

# %% [markdown]
# # Get only rows which contain the last training epoch

# %%
min_loss_idx_per_uuid = model_epochs_df.groupby('uuid')['epoch'].idxmax()
min_loss_per_uuid_df = model_epochs_df.loc[min_loss_idx_per_uuid]
min_loss_per_uuid_df
# Out:
#                         timestamp  learning_rate            model_type
# 9371   2024-02-11 06:29:50.948842         0.0003  SIMPLE_300-SKIP_N_20  \
# 16235  2024-02-11 05:22:10.865951         0.0003  SIMPLE_300-SKIP_N_20
# 1517   2024-02-11 05:15:37.366601         0.0003  SIMPLE_300-SKIP_N_20
# 6071   2024-02-11 06:04:07.917424         0.0003  SIMPLE_300-SKIP_N_20
# 5015   2024-02-11 06:30:08.708837         0.0003  SIMPLE_300-SKIP_N_20
# ...                           ...            ...                   ...
# 10295  2024-02-11 06:03:56.985354         0.0003  SIMPLE_300-SKIP_N_20
# 10955  2024-02-11 05:11:18.788354         0.0003  SIMPLE_300-SKIP_N_20
# 2903   2024-02-11 05:22:09.825943         0.0003  SIMPLE_300-SKIP_N_20
# 2837   2024-02-11 06:10:42.710883         0.0003  SIMPLE_300-SKIP_N_20
# 16037  2024-02-11 06:15:48.602010         0.0003  SIMPLE_300-SKIP_N_20
#
#       train_or_test  epoch          loss                 model_parameters
# 9371           TEST     60 1.7460025e-06  skip_20_LR_0.0003_LAYERSIZE_300  \
# 16235          TEST     60 1.8950301e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 1517           TEST     60 1.6565132e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 6071           TEST     60 1.7115377e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 5015           TEST     60 1.7415188e-06  skip_20_LR_0.0003_LAYERSIZE_300
# ...             ...    ...           ...                              ...
# 10295          TEST     60 1.7179635e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 10955          TEST     60 1.8778233e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 2903           TEST     60 1.7260769e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 2837           TEST     60 1.8423693e-06  skip_20_LR_0.0003_LAYERSIZE_300
# 16037          TEST     60 1.7218211e-06  skip_20_LR_0.0003_LAYERSIZE_300
#
#                                        uuid
# 9371   010cf3f4-41a5-4c5b-bfae-52b05932ba51
# 16235  0128ca94-df55-4628-8f24-bd8838cc9456
# 1517   0159d3ed-fc45-4b3f-b4cd-442beb8a10cd
# 6071   0218953d-6402-4fcf-b499-f41b379197d6
# 5015   027bf402-a398-4c4b-84aa-dd6b8f7b865b
# ...                                     ...
# 10295  fcf15026-bfb0-4211-ab97-01e135c3be1f
# 10955  fd85be7e-f9ed-4dff-b4df-b6a130e79721
# 2903   fdaf5b5f-e6ff-455a-b00d-bbda5c3d45d9
# 2837   fde71007-5b52-4f9d-b5c2-36a6933afd36
# 16037  fe2d346d-6e49-46e3-b85e-b9218f8dec00
#
# [404 rows x 8 columns]

# %% [markdown]
# # Is the minimum test loss correlated to the rollout performance?
# It doesn't seem to have such a strong correlation, but that is also due to the fact that the models have very similar performance on the test dataset

# %%
# Merge DataFrames on 'uuid' column
merged_df = pd.merge(model_eval_df, min_loss_per_uuid_df, on=['uuid'])

# Perform further analysis or visualization
# For example, calculate correlation between rollout_error and min test loss
correlation = merged_df['rollout_error'].corr(merged_df['loss'])
print("Correlation between rollout_error and min test loss:", correlation)
# Out:
# Correlation between rollout_error and min test loss: 0.11055848225910517

# %%
# Display the merged DataFrame
merged_df.sort_values(by='rollout_error')
# Out:
#      rollout_error      avg_error               model_parameters_x
# 316      82.091004    0.082091004  skip_20_LR_0.0003_LAYERSIZE_300  \
# 295      104.52434     0.10452434  skip_20_LR_0.0003_LAYERSIZE_300
# 385      107.36449     0.10736449  skip_20_LR_0.0003_LAYERSIZE_300
# 296      108.26791     0.10826791  skip_20_LR_0.0003_LAYERSIZE_300
# 332      114.39371     0.11439371  skip_20_LR_0.0003_LAYERSIZE_300
# ..             ...            ...                              ...
# 106  9.4095399e+90  9.4095399e+87  skip_20_LR_0.0003_LAYERSIZE_300
# 195 1.7046678e+107 1.7046678e+104  skip_20_LR_0.0003_LAYERSIZE_300
# 1   2.0836359e+112 2.0836359e+109  skip_20_LR_0.0003_LAYERSIZE_300
# 335 3.7553374e+117 3.7553374e+114  skip_20_LR_0.0003_LAYERSIZE_300
# 133 3.2359728e+119 3.2359728e+116  skip_20_LR_0.0003_LAYERSIZE_300
#
#                                      uuid                   timestamp
# 316  47c0009f-3db0-42d4-b2c3-57b9d7baf2c3  2024-02-11 05:23:13.430702  \
# 295  0e7f8142-cd1f-4cd6-85c0-19c461953d2d  2024-02-11 05:20:52.554663
# 385  baccf63b-dbd3-4b48-a1d3-11edd4b3b29b  2024-02-11 06:27:38.048771
# 296  086fa3a8-1468-4fc1-8541-e9c032ffb5c0  2024-02-11 06:30:01.725133
# 332  191aed02-2a5d-400d-9cce-1a14c625f22f  2024-02-11 06:29:20.624283
# ..                                    ...                         ...
# 106  1eea0142-a6c5-4389-ba4b-4e19b617e0a2  2024-02-11 06:19:34.299506
# 195  3ec5ad73-ff04-4cfa-9408-5a9f994487cb  2024-02-11 06:27:36.230296
# 1    995f1a37-d50b-4d56-bde8-e056b3c6dbaa  2024-02-11 05:06:52.842043
# 335  eba610e2-91fc-425a-941c-380b17d5f90d  2024-02-11 05:22:05.981770
# 133  3f3b170c-bd9b-4571-8e3a-1e60add8a6f1  2024-02-11 05:25:46.645226
#
#      learning_rate            model_type train_or_test  epoch          loss
# 316         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.7916895e-06  \
# 295         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.6942923e-06
# 385         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.7438458e-06
# 296         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.6814502e-06
# 332         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.7142623e-06
# ..             ...                   ...           ...    ...           ...
# 106         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.7833778e-06
# 195         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.7094254e-06
# 1           0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.7237378e-06
# 335         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.6944037e-06
# 133         0.0003  SIMPLE_300-SKIP_N_20          TEST     60 1.8557937e-06
#
#                   model_parameters_y
# 316  skip_20_LR_0.0003_LAYERSIZE_300
# 295  skip_20_LR_0.0003_LAYERSIZE_300
# 385  skip_20_LR_0.0003_LAYERSIZE_300
# 296  skip_20_LR_0.0003_LAYERSIZE_300
# 332  skip_20_LR_0.0003_LAYERSIZE_300
# ..                               ...
# 106  skip_20_LR_0.0003_LAYERSIZE_300
# 195  skip_20_LR_0.0003_LAYERSIZE_300
# 1    skip_20_LR_0.0003_LAYERSIZE_300
# 335  skip_20_LR_0.0003_LAYERSIZE_300
# 133  skip_20_LR_0.0003_LAYERSIZE_300
#
# [404 rows x 11 columns]

# %% [markdown]
# # Print the directory paths of the best performing models

# %%
best_models_df = merged_df.sort_values(by='rollout_error', ascending=True).head(5)[["model_parameters_x", "uuid"]]

# %%
best_models_df['path'] = best_models_df.apply(lambda row: row["model_parameters_x"] + "/" + row["uuid"], axis=1)
