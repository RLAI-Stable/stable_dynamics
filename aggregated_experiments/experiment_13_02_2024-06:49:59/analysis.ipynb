# %% [markdown]
# # Load files

# %%
import pandas as pd
pd.options.display.float_format = '{:.8}'.format


# Read CSV files into pandas DataFrames
model_eval_df = pd.read_csv('model_eval.csv')
model_epochs_df = pd.read_csv('model_epochs.csv')

# %% [markdown]
# # Filter epochs DF to get only the test loss

# %%
model_epochs_df = model_epochs_df[model_epochs_df['train_or_test'] == 'TEST']
display(model_epochs_df)
# Out:
#                         timestamp  learning_rate            model_type  \
# 15     2024-02-11 13:39:47.594037          0.001  STABLE_300-SKIP_N_20
# 31     2024-02-11 13:58:19.687725          0.001  STABLE_300-SKIP_N_20
# 47     2024-02-11 14:16:53.994537          0.001  STABLE_300-SKIP_N_20
# 63     2024-02-11 14:35:26.435440          0.001  STABLE_300-SKIP_N_20
# 79     2024-02-11 07:00:06.260236          0.001  STABLE_300-SKIP_N_20
# ...                           ...            ...                   ...
# 32767  2024-02-11 16:38:46.878911          0.001  STABLE_300-SKIP_N_20
# 32783  2024-02-11 18:00:41.186736          0.001  STABLE_300-SKIP_N_20
# 32799  2024-02-11 18:24:57.999090          0.001  STABLE_300-SKIP_N_20
# 32815  2024-02-11 18:49:09.965141          0.001  STABLE_300-SKIP_N_20
# 32831  2024-02-11 19:13:57.451855          0.001  STABLE_300-SKIP_N_20
#
#       train_or_test  epoch          loss                model_parameters  \
# 15             TEST     15  2.099148e-06  skip_20_LR_0.001_LAYERSIZE_300
# 31             TEST     30 1.8331399e-06  skip_20_LR_0.001_LAYERSIZE_300
# 47             TEST     45 2.0372471e-06  skip_20_LR_0.001_LAYERSIZE_300
# 63             TEST     60 1.6576253e-06  skip_20_LR_0.001_LAYERSIZE_300
# 79             TEST     15 2.0538431e-06  skip_20_LR_0.001_LAYERSIZE_300
# ...             ...    ...           ...                             ...
# 32767          TEST     60 1.6356286e-06  skip_20_LR_0.001_LAYERSIZE_300
# 32783          TEST     15 2.0021401e-06  skip_20_LR_0.001_LAYERSIZE_300
# 32799          TEST     30 1.8737902e-06  skip_20_LR_0.001_LAYERSIZE_300
# 32815          TEST     45 1.6880305e-06  skip_20_LR_0.001_LAYERSIZE_300
# 32831          TEST     60 1.5821254e-06  skip_20_LR_0.001_LAYERSIZE_300
#
#                                        uuid
# 15     a3984f9a-a4ab-4d82-b653-83629b42a5b9
# 31     a3984f9a-a4ab-4d82-b653-83629b42a5b9
# 47     a3984f9a-a4ab-4d82-b653-83629b42a5b9
# 63     a3984f9a-a4ab-4d82-b653-83629b42a5b9
# 79     4893cbde-5329-48f0-bba3-c2a6aeed2b4a
# ...                                     ...
# 32767  ee9c8527-2da1-48a1-bcfa-4da38b4cf105
# 32783  9715cc40-3aac-419b-a353-c36f6cf27571
# 32799  9715cc40-3aac-419b-a353-c36f6cf27571
# 32815  9715cc40-3aac-419b-a353-c36f6cf27571
# 32831  9715cc40-3aac-419b-a353-c36f6cf27571
#
# [2052 rows x 8 columns]

# %% [markdown]
# # Get only rows which contain the last training epoch

# %%
min_loss_idx_per_uuid = model_epochs_df.groupby('uuid')['epoch'].idxmax()
min_loss_per_uuid_df = model_epochs_df.loc[min_loss_idx_per_uuid]
min_loss_per_uuid_df
# Out:
#                         timestamp  learning_rate            model_type  \
# 26111  2024-02-11 15:27:25.902087          0.001  STABLE_300-SKIP_N_20
# 18943  2024-02-11 15:18:58.542145          0.001  STABLE_300-SKIP_N_20
# 3263   2024-02-11 12:59:52.472042          0.001  STABLE_300-SKIP_N_20
# 29503  2024-02-11 15:05:30.465901          0.001  STABLE_300-SKIP_N_20
# 18175  2024-02-11 14:22:02.457178          0.001  STABLE_300-SKIP_N_20
# ...                           ...            ...                   ...
# 18303  2024-02-11 07:25:13.061952          0.001  STABLE_300-SKIP_N_20
# 7423   2024-02-11 16:00:25.616775          0.001  STABLE_300-SKIP_N_20
# 20287  2024-02-11 13:38:35.158679          0.001  STABLE_300-SKIP_N_20
# 10111  2024-02-11 08:19:03.012914          0.001  STABLE_300-SKIP_N_20
# 20543  2024-02-11 08:07:28.245580          0.001  STABLE_300-SKIP_N_20
#
#       train_or_test  epoch          loss                model_parameters  \
# 26111          TEST     60 1.6328049e-06  skip_20_LR_0.001_LAYERSIZE_300
# 18943          TEST     60 1.8314505e-06  skip_20_LR_0.001_LAYERSIZE_300
# 3263           TEST     60 1.7215918e-06  skip_20_LR_0.001_LAYERSIZE_300
# 29503          TEST     60 1.7092886e-06  skip_20_LR_0.001_LAYERSIZE_300
# 18175          TEST     60 1.7431282e-06  skip_20_LR_0.001_LAYERSIZE_300
# ...             ...    ...           ...                             ...
# 18303          TEST     60 1.6517445e-06  skip_20_LR_0.001_LAYERSIZE_300
# 7423           TEST     60 1.6310744e-06  skip_20_LR_0.001_LAYERSIZE_300
# 20287          TEST     60 1.6101924e-06  skip_20_LR_0.001_LAYERSIZE_300
# 10111          TEST     60 1.6920957e-06  skip_20_LR_0.001_LAYERSIZE_300
# 20543          TEST     60 1.6543947e-06  skip_20_LR_0.001_LAYERSIZE_300
#
#                                        uuid
# 26111  0042dc0b-05c0-4597-b120-ddbcf89c5cb6
# 18943  010b5dcf-7391-400c-96bd-b37cc929c224
# 3263   017264ae-239f-419e-b4f0-7b2a60506f51
# 29503  019c78b9-cc93-4cb2-8430-5be6d7c9f742
# 18175  01aff0c3-30ea-4d8f-8a00-bd18efdcf80a
# ...                                     ...
# 18303  fa47094f-0335-42f4-938b-b4fa8ec36411
# 7423   faaf142a-a97a-4841-9bdb-b78e8982e9e0
# 20287  fd10c989-b39e-4fe9-af22-a09750ebc45d
# 10111  ff85f977-7041-4fe0-b8d1-1954047bd210
# 20543  ffd62fe0-1dc0-4f26-ab83-84589f76fb6b
#
# [513 rows x 8 columns]

# %% [markdown]
# # Is the minimum test loss correlated to the rollout performance?
# It doesn't seem to have such a strong correlation, but that is also due to the fact that the models have very similar performance on the test dataset

# %%
# Merge DataFrames on 'uuid' column
merged_df = pd.merge(model_eval_df, min_loss_per_uuid_df, on=['uuid'])

# Perform further analysis or visualization
# For example, calculate correlation between rollout_error and min test loss
correlation = merged_df['rollout_error'].corr(merged_df['loss'])
print("Correlation between rollout_error and min test loss:", correlation)
# Out:
# Correlation between rollout_error and min test loss: 0.0006538772505694354

# %%
# Display the merged DataFrame
merged_df.sort_values(by='rollout_error')
# Out:
#      rollout_error      avg_error              model_parameters_x  \
# 380      64.445174    0.064445174  skip_20_LR_0.001_LAYERSIZE_300
# 405      70.028928    0.070028928  skip_20_LR_0.001_LAYERSIZE_300
# 51       72.766496    0.072766496  skip_20_LR_0.001_LAYERSIZE_300
# 7        85.810436    0.085810436  skip_20_LR_0.001_LAYERSIZE_300
# 500      86.922805    0.086922805  skip_20_LR_0.001_LAYERSIZE_300
# ..             ...            ...                             ...
# 40       412965.52      412.96552  skip_20_LR_0.001_LAYERSIZE_300
# 412      488886.03      488.88603  skip_20_LR_0.001_LAYERSIZE_300
# 48       576744.39      576.74439  skip_20_LR_0.001_LAYERSIZE_300
# 151  3.1102959e+07      31102.959  skip_20_LR_0.001_LAYERSIZE_300
# 263 1.2631143e+122 1.2631143e+119  skip_20_LR_0.001_LAYERSIZE_300
#
#                                      uuid                   timestamp  \
# 380  c4c14031-2f13-4cb5-bb4f-c6f8cc3acc13  2024-02-11 21:40:51.089350
# 405  f4996b04-c06b-4715-911b-c5ffd79e58ed  2024-02-11 12:19:37.356900
# 51   965603d5-f82b-4785-b17c-2c028c1b4a24  2024-02-11 13:44:39.073239
# 7    3782bca4-a48a-4cbc-a07d-5fa08affbb5c  2024-02-11 14:52:13.317799
# 500  8aa9cbe4-f4bc-44b7-a327-69a517a5abca  2024-02-11 09:26:47.865486
# ..                                    ...                         ...
# 40   dc62aece-13f9-418c-aa7e-e34cc557842f  2024-02-11 21:59:14.104867
# 412  1da38041-8150-44dc-b0c6-ed3360508c7d  2024-02-11 20:17:55.050982
# 48   76079099-fb53-4325-a455-477707862173  2024-02-11 21:57:07.929455
# 151  0952c288-47f7-44bc-9e87-895af2a6980a  2024-02-11 19:15:33.500960
# 263  d7f6d339-1b6e-4243-8e4b-699725b4329e  2024-02-11 15:54:56.971470
#
#      learning_rate            model_type train_or_test  epoch          loss  \
# 380          0.001  STABLE_300-SKIP_N_20          TEST     60 1.6227271e-06
# 405          0.001  STABLE_300-SKIP_N_20          TEST     60 1.6775977e-06
# 51           0.001  STABLE_300-SKIP_N_20          TEST     60 1.6847512e-06
# 7            0.001  STABLE_300-SKIP_N_20          TEST     60 1.9346875e-06
# 500          0.001  STABLE_300-SKIP_N_20          TEST     60 1.6084837e-06
# ..             ...                   ...           ...    ...           ...
# 40           0.001  STABLE_300-SKIP_N_20          TEST     60 1.7865439e-06
# 412          0.001  STABLE_300-SKIP_N_20          TEST     60 1.6449297e-06
# 48           0.001  STABLE_300-SKIP_N_20          TEST     60 1.6129037e-06
# 151          0.001  STABLE_300-SKIP_N_20          TEST     60 1.6023784e-06
# 263          0.001  STABLE_300-SKIP_N_20          TEST     60 1.6854282e-06
#
#                  model_parameters_y
# 380  skip_20_LR_0.001_LAYERSIZE_300
# 405  skip_20_LR_0.001_LAYERSIZE_300
# 51   skip_20_LR_0.001_LAYERSIZE_300
# 7    skip_20_LR_0.001_LAYERSIZE_300
# 500  skip_20_LR_0.001_LAYERSIZE_300
# ..                              ...
# 40   skip_20_LR_0.001_LAYERSIZE_300
# 412  skip_20_LR_0.001_LAYERSIZE_300
# 48   skip_20_LR_0.001_LAYERSIZE_300
# 151  skip_20_LR_0.001_LAYERSIZE_300
# 263  skip_20_LR_0.001_LAYERSIZE_300
#
# [510 rows x 11 columns]

# %% [markdown]
# # Print the directory paths of the best performing models

# %%
best_models_df = merged_df.sort_values(by='rollout_error', ascending=True).head(5)[["model_parameters_x", "uuid"]]

# %%
best_models_df['path'] = best_models_df.apply(lambda row: row["model_parameters_x"] + "/" + row["uuid"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2d/h_7q9nsj7rgcghx8k0q3bfl00000gr/T/ipykernel_7015/4177441309.py in ?()
# ----> 1 best_models_df['path'] = best_models_df.apply(lambda row: row["model_parameters_x"] + "/" + best_models_df["uuid"], axis=1)
#
# ~/projects/stable_dynamics/stabledynamicsenv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4285             self._setitem_frame(key, value)
#    4286         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4287             self._setitem_array(key, value)
#    4288         elif isinstance(value, DataFrame):
# -> 4289             self._set_item_frame_value(key, value)
#    4290         elif (
#    4291             is_list_like(value)
#    4292             and not self.columns.is_unique
#
# ~/projects/stable_dynamics/stabledynamicsenv/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4443
#    4444             return self.isetitem(locs, value)
#    4445
#    4446         if len(value.columns) > 1:
# -> 4447             raise ValueError(
#    4448                 "Cannot set a DataFrame with multiple columns to the single "
#    4449                 f"column {key}"
#    4450             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column path
